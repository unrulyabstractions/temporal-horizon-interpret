# %% [markdown]
# # Dataset Exploration
#
# This notebook explores the generated temporal horizon dataset.

# %%
import sys
sys.path.append('..')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.dataset.loader import load_dataset, get_dataset_statistics

# %%
# Load dataset
dataset = load_dataset('../data/raw/prompts.jsonl')
print(f"Loaded {len(dataset)} prompt pairs")

# %%
# Get statistics
stats = get_dataset_statistics(dataset)
print(stats)

# %%
# Visualize domain distribution
df = pd.DataFrame(dataset)
df['domain'].value_counts().plot(kind='bar')
plt.title('Domain Distribution')
plt.show()
